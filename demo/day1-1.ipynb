# %% [markdown]
# 1. Show AoC Website
# 2. Walk through the website, show the login, show the problem, show the input
# 3. Create a new workspace in VSCode
# 4. Create an input file
# 5. Create a new python file, open the input file
# 6. Allow students time to think about and solve the problem
# 7. Solve the assignment and show how to program and submit the answer
# 8. Show the leaderboard

# %%
import string

numbers = [str(x) for x in range(10)]

nums = []

for line in lines:
    first, last = None, None
    for char in line:
        if char in numbers:
            if not first:
                first = char
            last = char
    nums.append(int(first+last))

sum(nums)
